# %%
## Import libraries for the project

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import linear_model
from sklearn.svm import SVR
from scipy import stats

import os

# %%
## Load the dataset
bc_df = pd.read_csv('C:\\Users\\user\\Desktop\\DataScience\\BreastCancer\\data.csv')
bc_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
## introducing a heatmap to display all the pairwise correlation values
plt.figure(figsize=(20,20))
sns.heatmap(bc_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Change the M: Malignant and B: Benign in the diagnosis column
bc_df['diagnosis'] = bc_df.diagnosis.map({"M":"Malignant",
                               "B":"benign"})
bc_df['diagnosis'].value_counts()
# Out:
# benign       357
# Malignant    212
# Name: diagnosis, dtype: int64
